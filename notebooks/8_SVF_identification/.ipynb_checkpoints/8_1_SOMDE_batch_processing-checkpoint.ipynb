# %% [markdown]
# # Aim of the notebook

# %% [markdown]
# In this notebook we apply sinfonia to identify Spatially variable genes across xenium datasets
#
# ##########Script working on SOMDE (Bioinformatics doi: 10.1093/bioinformatics/btab471)######################
#
# ## IMPORTANT: Please use the conda environment in somde.yml (same folder)

# %% [markdown]
# ## Import packages

# %%
from somde import SomNode
import scanpy as sc
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy as np
import os
import random

# %% [markdown]
# ## Definie paths and files to analyze

# %%
maindir='../../data/unprocessed_adata/'
output_dir='../../data/unprocessed_adata_nuclei/'
files=os.listdir(maindir)
files=['ms_brain_multisection1.h5ad', 'human_brain.h5ad', 'ms_brain_multisection2.h5ad', 'ms_brain_multisection3.h5ad',
'realmouse_1.h5ad', 'realmouse_2.h5ad', 'realmouse_3.h5ad','realmouse_4.h5ad', 'hbreast_ilc_addon_set2.h5ad',
'hbreast_ilc_addon_set4.h5ad', 'hbreast_ilc_entiresample_set3.h5ad', 'healthy_lung.h5ad', 'human_alzheimers.h5ad',
 'human_gbm.h5ad', 'human_spinal_chord_active.h5ad', 'human_spinal_chord_inactive.h5ad', 'h_breast_1.h5ad',
 'h_breast_2.h5ad', 'lung_cancer.h5ad', 'ms_brain_fullcoronal.h5ad', 'ms_brain_partialcoronal.h5ad' ]

# %%
for f in files[:]:
    try:
        print(f)
        adata=sc.read(output_dir+f)
        adata.obsm["spatial"]=np.array([adata.obs.x_centroid,adata.obs.y_centroid]).transpose().astype('float32')
        some=random.sample(range(0,adata.shape[0]),5000)
        adata=adata[some,:]
        df=pd.DataFrame(adata.X,columns=adata.var.index)
        df=df.fillna(0)
        corinfo = adata.obs
        corinfo["total_count"]=df.sum(0)
        X=corinfo[['x_centroid','y_centroid']].values.astype(np.float32)
        som = SomNode(X,10)
        ndf,ninfo = som.mtx(df.transpose())
        ndf=ndf.astype(float)
        nres = som.norm()
        result, SVnum =som.run()
        result.index=result['g']
        result['rank']=result.loc[:,['LLR']].rank()
        result=result.loc[:,['pval','qval','rank']]
        result.columns=['Pval','FDR','rank']
        result.to_csv('../../figures/SVF/'+str(f.split('.')[0])+'__somde.csv')
    except:
        print('not possible')
# Out:
# ms_brain_multisection1.h5ad
# /tmp/ipykernel_592911/2781915168.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   corinfo["total_count"]=df.sum(0)
# using 22*22 SOM nodes for 5000 points
# ...
# Models: 100%|███████████████████████████████████████████████████████████████████████████| 10/10 [00:35<00:00,  3.59s/it]
# human_brain.h5ad
# using 22*22 SOM nodes for 5000 points
# /tmp/ipykernel_592911/2781915168.py:14: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   corinfo["total_count"]=df.sum(0)
# ...
#  94%|██████████████████████████████████████████████████████████████████████████▉     | 507/541 [00:05<00:00, 105.59it/s]
# ...
# ...
# Models: 100%|███████████████████████████████████████████████████████████████████████████| 10/10 [00:37<00:00,  3.75s/it]

# %%
result.index=result['g']

# %% [markdown]
# ## Calculate the computing times

# %%
import time
import random
f='ms_brain_multisection1.h5ad'
cells=[500,1000,5000,10000,50000,100000]
times=[]
for cel in cells:
    print(f)
    start_time = time.time()
    adata=sc.read(output_dir+f)
    adata.obsm["spatial"]=np.array([adata.obs.x_centroid,adata.obs.y_centroid]).transpose().astype('float32')
    #adata=adata[adata.obs['replicate']=='1']
    #sc.pp.subsample(adata,0.1)
    some=random.sample(range(0,adata.shape[0]),int(cel))
    adata=adata[some,:]
    adata=adata[:,np.sum(adata.X,axis=0)>0]
    df=pd.DataFrame(adata.X,columns=adata.var.index)
    df=df.fillna(0)
    corinfo = adata.obs
    corinfo["total_count"]=df.sum(0)
    X=corinfo[['x_centroid','y_centroid']].values.astype(np.float32)
    som = SomNode(X,10)
    ndf,ninfo = som.mtx(df.transpose())
    ndf=ndf.astype(float)
    nres = som.norm()
    result, SVnum =som.run()
    result.index=result['g']
    result['rank']=result.loc[:,['LLR']].rank()
    result=result.loc[:,['pval','qval','rank']]
    result.columns=['Pval','FDR','rank']
    end_time = time.time()
    times.append(end_time-start_time)
# Out:
# ms_brain_multisection1.h5ad
# /tmp/ipykernel_592911/1642858582.py:19: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   corinfo["total_count"]=df.sum(0)
# using 7*7 SOM nodes for 500 points
# ...
# Models: 100%|███████████████████████████████████████████████████████████████████████████| 10/10 [00:19<00:00,  1.91s/it]
# ms_brain_multisection1.h5ad
# /tmp/ipykernel_592911/1642858582.py:19: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   corinfo["total_count"]=df.sum(0)
# using 10*10 SOM nodes for 1000 points
# ...
#   8%|██████▌                                                                          | 42/514 [00:00<00:02, 208.86it/s]
# ...
# ...
#  65%|█████████████████████████████████████████████████████                            | 354/541 [00:08<00:04, 39.77it/s]

# %%
timesres=pd.DataFrame([cells,times],index=['cells','times_somde']).transpose()
plt.plot(list(timesres['cells'].astype(int)),list(timesres['times_somde'].astype(float)))
timesres.to_csv('../../figures/times_svf/somde_times.csv')
