# %% [markdown]
# # Aim of the notebook

# %% [markdown]
# This notebook is used to identify tissue domains using SpaGCN

# %%
import platform
platform.python_version()
# Out:
# '3.8.8'

# %% [markdown]
# ### 2. Import python modules

# %%
import os,csv,re
import pandas as pd
import numpy as np
import scanpy as sc
import math
import SpaGCN as spg
from scipy.sparse import issparse
import random, torch
import warnings
warnings.filterwarnings("ignore")
import matplotlib.colors as clr
import matplotlib.pyplot as plt
import SpaGCN as spg
#In order to read in image data, we need to install some package. Here we recommend package "opencv"
#inatll opencv in python
#!pip3 install opencv-python
import cv2
import tiffile as tff

# %% [markdown]
# ### 3. Read in data
# The current version of SpaGCN requres three input data:
# <br>
# 1. The gene expression matrix(n by k): expression_matrix.h5;
# <br>
# 2. Spatial coordinateds of samplespositions.txt;
# <br>
# 3. Histology image(optional): histology.tif, can be tif or png or jepg.
# <br>
# The gene expreesion data can be stored as an AnnData object. AnnData stores a data matrix .X together with annotations of observations .obs, variables .var and unstructured annotations .uns.

# %%
saving_path=r'../../data/processed_adata/'
adata=sc.read('../../data/processed_adata/adata_multisection_nuclei_r1_with_annotations.h5ad')
adata.X=adata.layers['raw']

# %% [markdown]
# ### Select ROI1

# %%
adata2=adata[(adata.obs['x_centroid']<5000)&(adata.obs['x_centroid']>2000)&(adata.obs['y_centroid']>4000)]
plt.scatter(adata.obs.loc[:,'x_centroid'],adata.obs.loc[:,'y_centroid'],s=0.1)
plt.scatter(adata2.obs.loc[:,'x_centroid'],adata2.obs.loc[:,'y_centroid'],s=0.1)
adata=adata2

# %% [markdown]
# ### 4. Integrate gene expression and histology into a Graph

# %% [markdown]
# ### 5. Spatial domain detection using SpaGCN

# %% [markdown]
# #### 5.1 Expression data preprocessing

# %% [markdown]
# #### 5.2 Set hyper-parameters

# %% [markdown]
# - p: Percentage of total expression contributed by neighborhoods.
# - l: Parameter to control p.

# %%
adata.obs['x_pixel']=adata.obs['X']
adata.obs['y_pixel']=adata.obs['Y']
adata.obs['x_array']=adata.obs['X']
adata.obs['y_array']=adata.obs['Y']
#Set coordinates
x_array=adata.obs["x_array"].tolist()
y_array=adata.obs["y_array"].tolist()
x_pixel=adata.obs["x_pixel"].tolist()
y_pixel=adata.obs["y_pixel"].tolist()

#Calculate adjacent matrix
s=0
b=49
ndoms=[]
for num in range(1,5):
    ndoms.append(len(np.unique(adata.obs['region_level'+str(num)])))
#adj=spg.calculate_adj_matrix(x=x_pixel,y=y_pixel, x_pixel=x_pixel, y_pixel=y_pixel, image=img, beta=b, alpha=s, histology=True)
#If histlogy image is not available, SpaGCN can calculate the adjacent matrix using the fnction below
adj=spg.calculate_adj_matrix(x=x_pixel,y=y_pixel, histology=False)
#np.savetxt('./data/151673/adj.csv', adj, delimiter=',')
adata.var_names_make_unique()
spg.prefilter_genes(adata,min_cells=3) # avoiding all genes are zeros
spg.prefilter_specialgenes(adata)
#Normalize and take log for UMI
sc.pp.normalize_per_cell(adata)
sc.pp.log1p(adata)
ps=[0.3,0.5,0.7,0.9] 
for p in ps:
    #Find the l value given p
    l=spg.search_l(p, adj, start=0.01, end=100, tol=0.01, max_run=100)
    for n_clusters in ndoms:
        #Set seed
        r_seed=t_seed=n_seed=100
        #Seaech for suitable resolution
        res=spg.search_res(adata, adj, l, n_clusters, start=0.2+(0.05*n_clusters), step=0.1, tol=5e-3, lr=0.05, max_epochs=20, r_seed=r_seed, t_seed=t_seed, n_seed=n_seed)
        clf=spg.SpaGCN()
        clf.set_l(l)
        #Set seed
        random.seed(r_seed)
        torch.manual_seed(t_seed)
        np.random.seed(n_seed)
        #Run
        clf.train(adata,adj,init_spa=True,init="louvain",res=res, tol=5e-3, lr=0.05, max_epochs=200)
        y_pred, prob=clf.predict()
        adata.obs["pred"]= y_pred
        adata.obs["pred"]=adata.obs["pred"].astype('category')
        #Do cluster refinement(optional)
        #shape="hexagon" for Visium data, "square" for ST data.
        adj_2d=spg.calculate_adj_matrix(x=x_array,y=y_array, histology=False)
        refined_pred=spg.refine(sample_id=adata.obs.index.tolist(), pred=adata.obs["pred"].tolist(), dis=adj_2d, shape="hexagon")
        adata.obs["refined_pred"]=refined_pred
        adata.obs["refined_pred"]=adata.obs["refined_pred"].astype('category')
        #Save results
        #adata.write_h5ad("./sample_results/results.h5ad")
        adata.obsm['spatial']=np.array(adata.obs.loc[:,['x_centroid','y_centroid']])
        sc.pl.spatial(adata,color='refined_pred',spot_size=30)
        results=adata.obs.loc[:,['cell_id','refined_pred']]
        results.columns=['cell_id','spatial_domain']
        results.to_csv('../../figures/7.spatial_architecture/domains_predicted/ROI1/'+str(n_clusters)+'/predicted_SpaGCN_P'+str(p)+'.csv')
# Out:
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 100], p [0.0, 12.137574195861816]
# Run 2: l [0.01, 50.005], p [0.0, 2.731995105743408]
# Run 3: l [0.01, 25.0075], p [0.0, 0.37146270275115967]
# Run 4: l [12.508750000000001, 25.0075], p [0.015317559242248535, 0.37146270275115967]
# Run 5: l [18.758125, 25.0075], p [0.12164998054504395, 0.37146270275115967]
# Run 6: l [21.8828125, 25.0075], p [0.22778737545013428, 0.37146270275115967]
# recommended l =  23.44515625
# Start at res =  0.5 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.5
# Epoch  0
# Epoch  10
# Res =  0.5 Num of clusters =  21
# Initializing cluster centers with louvain, resolution =  0.4
# Epoch  0
# Epoch  10
# Res =  0.4 Num of clusters =  18
# Res changed to 0.4
# Initializing cluster centers with louvain, resolution =  0.30000000000000004
# Epoch  0
# Epoch  10
# delta_label  0.004264916957145786 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.30000000000000004 Num of clusters =  18
# Res changed to 0.30000000000000004
# Initializing cluster centers with louvain, resolution =  0.20000000000000004
# Epoch  0
# Epoch  10
# Res =  0.20000000000000004 Num of clusters =  16
# Res changed to 0.20000000000000004
# Initializing cluster centers with louvain, resolution =  0.10000000000000003
# Epoch  0
# Epoch  10
# Res =  0.10000000000000003 Num of clusters =  12
# Res changed to 0.10000000000000003
# Initializing cluster centers with louvain, resolution =  2.7755575615628914e-17
# Epoch  0
# delta_label  0.0 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 1
# Res =  2.7755575615628914e-17 Num of clusters =  1
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.05000000000000003
# Epoch  0
# Epoch  10
# delta_label  0.004551978675415214 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.05000000000000003 Num of clusters =  7
# Res changed to 0.05000000000000003
# Initializing cluster centers with louvain, resolution =  2.7755575615628914e-17
# Epoch  0
# delta_label  0.0 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 1
# Res =  2.7755575615628914e-17 Num of clusters =  1
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.02500000000000003
# Epoch  0
# Epoch  10
# delta_label  0.0038958376050850932 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 13
# Res =  0.02500000000000003 Num of clusters =  4
# Step changed to 0.0125
# Initializing cluster centers with louvain, resolution =  0.03750000000000003
# Epoch  0
# Epoch  10
# delta_label  0.0037728111543981957 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 13
# Res =  0.03750000000000003 Num of clusters =  4
# Step changed to 0.00625
# Initializing cluster centers with louvain, resolution =  0.04375000000000003
# Epoch  0
# Epoch  10
# Res =  0.04375000000000003 Num of clusters =  7
# Res changed to 0.04375000000000003
# Initializing cluster centers with louvain, resolution =  0.03750000000000003
# Epoch  0
# Epoch  10
# delta_label  0.0037728111543981957 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 13
# Res =  0.03750000000000003 Num of clusters =  4
# Step changed to 0.003125
# Initializing cluster centers with louvain, resolution =  0.04062500000000003
# Epoch  0
# Epoch  10
# delta_label  0.0038958376050850932 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 16
# Res =  0.04062500000000003 Num of clusters =  6
# recommended res =  0.04062500000000003
# Initializing cluster centers with louvain, resolution =  0.04062500000000003
# Epoch  0
# Epoch  10
# delta_label  0.0038958376050850932 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 16
# Calculateing adj matrix using xy only...
# Start at res =  0.65 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.65
# Epoch  0
# Epoch  10
# Res =  0.65 Num of clusters =  19
# Initializing cluster centers with louvain, resolution =  0.55
# Epoch  0
# Epoch  10
# Res =  0.55 Num of clusters =  19
# Res changed to 0.55
# Initializing cluster centers with louvain, resolution =  0.45000000000000007
# Epoch  0
# Epoch  10
# Res =  0.45000000000000007 Num of clusters =  19
# Res changed to 0.45000000000000007
# Initializing cluster centers with louvain, resolution =  0.3500000000000001
# Epoch  0
# Epoch  10
# delta_label  0.004387943407832684 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.3500000000000001 Num of clusters =  18
# Res changed to 0.3500000000000001
# Initializing cluster centers with louvain, resolution =  0.2500000000000001
# Epoch  0
# Epoch  10
# Res =  0.2500000000000001 Num of clusters =  18
# Res changed to 0.2500000000000001
# Initializing cluster centers with louvain, resolution =  0.1500000000000001
# Epoch  0
# Epoch  10
# Res =  0.1500000000000001 Num of clusters =  14
# Res changed to 0.1500000000000001
# Initializing cluster centers with louvain, resolution =  0.0500000000000001
# Epoch  0
# Epoch  10
# delta_label  0.004551978675415214 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.0500000000000001 Num of clusters =  7
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.1000000000000001
# Epoch  0
# Epoch  10
# Res =  0.1000000000000001 Num of clusters =  12
# Res changed to 0.1000000000000001
# Initializing cluster centers with louvain, resolution =  0.0500000000000001
# Epoch  0
# Epoch  10
# delta_label  0.004551978675415214 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.0500000000000001 Num of clusters =  7
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.0750000000000001
# Epoch  0
# Epoch  10
# delta_label  0.004141890506458888 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 16
# Res =  0.0750000000000001 Num of clusters =  10
# Res changed to 0.0750000000000001
# Initializing cluster centers with louvain, resolution =  0.05000000000000009
# Epoch  0
# Epoch  10
# delta_label  0.004551978675415214 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.05000000000000009 Num of clusters =  7
# Step changed to 0.0125
# Initializing cluster centers with louvain, resolution =  0.0625000000000001
# Epoch  0
# Epoch  10
# delta_label  0.004387943407832684 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 16
# Res =  0.0625000000000001 Num of clusters =  8
# Step changed to 0.00625
# Initializing cluster centers with louvain, resolution =  0.06875000000000009
# Epoch  0
# Epoch  10
# delta_label  0.003280705351650605 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.06875000000000009 Num of clusters =  9
# recommended res =  0.06875000000000009
# Initializing cluster centers with louvain, resolution =  0.06875000000000009
# Epoch  0
# Epoch  10
# delta_label  0.003280705351650605 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Calculateing adj matrix using xy only...
# Start at res =  1.05 step =  0.1
# Initializing cluster centers with louvain, resolution =  1.05
# Epoch  0
# Epoch  10
# Res =  1.05 Num of clusters =  22
# Initializing cluster centers with louvain, resolution =  0.9500000000000001
# Epoch  0
# Epoch  10
# Res =  0.9500000000000001 Num of clusters =  21
# Res changed to 0.9500000000000001
# Initializing cluster centers with louvain, resolution =  0.8500000000000001
# Epoch  0
# Epoch  10
# Res =  0.8500000000000001 Num of clusters =  21
# Res changed to 0.8500000000000001
# Initializing cluster centers with louvain, resolution =  0.7500000000000001
# Epoch  0
# Epoch  10
# Res =  0.7500000000000001 Num of clusters =  21
# Res changed to 0.7500000000000001
# Initializing cluster centers with louvain, resolution =  0.6500000000000001
# Epoch  0
# Epoch  10
# Res =  0.6500000000000001 Num of clusters =  19
# Res changed to 0.6500000000000001
# Initializing cluster centers with louvain, resolution =  0.5500000000000002
# Epoch  0
# Epoch  10
# Res =  0.5500000000000002 Num of clusters =  19
# Res changed to 0.5500000000000002
# Initializing cluster centers with louvain, resolution =  0.4500000000000002
# Epoch  0
# Epoch  10
# Res =  0.4500000000000002 Num of clusters =  19
# Res changed to 0.4500000000000002
# Initializing cluster centers with louvain, resolution =  0.3500000000000002
# Epoch  0
# Epoch  10
# delta_label  0.004387943407832684 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.3500000000000002 Num of clusters =  18
# Res changed to 0.3500000000000002
# Initializing cluster centers with louvain, resolution =  0.2500000000000002
# Epoch  0
# Epoch  10
# Res =  0.2500000000000002 Num of clusters =  18
# Res changed to 0.2500000000000002
# Initializing cluster centers with louvain, resolution =  0.15000000000000022
# Epoch  0
# Epoch  10
# Res =  0.15000000000000022 Num of clusters =  14
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.20000000000000023
# Epoch  0
# Epoch  10
# Res =  0.20000000000000023 Num of clusters =  16
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.22500000000000023
# Epoch  0
# Epoch  10
# delta_label  0.00496206684437154 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 13
# Res =  0.22500000000000023 Num of clusters =  17
# recommended res =  0.22500000000000023
# Initializing cluster centers with louvain, resolution =  0.22500000000000023
# Epoch  0
# Epoch  10
# delta_label  0.00496206684437154 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 13
# Calculateing adj matrix using xy only...
# Start at res =  2.6500000000000004 step =  0.1
# Initializing cluster centers with louvain, resolution =  2.6500000000000004
# Epoch  0
# Epoch  10
# Res =  2.6500000000000004 Num of clusters =  37
# Initializing cluster centers with louvain, resolution =  2.7500000000000004
# Epoch  0
# Epoch  10
# Res =  2.7500000000000004 Num of clusters =  37
# Res changed to 2.7500000000000004
# Initializing cluster centers with louvain, resolution =  2.8500000000000005
# Epoch  0
# Epoch  10
# Res =  2.8500000000000005 Num of clusters =  37
# Res changed to 2.8500000000000005
# Initializing cluster centers with louvain, resolution =  2.9500000000000006
# Epoch  0
# Epoch  10
# Res =  2.9500000000000006 Num of clusters =  39
# Res changed to 2.9500000000000006
# Initializing cluster centers with louvain, resolution =  3.0500000000000007
# Epoch  0
# Epoch  10
# Res =  3.0500000000000007 Num of clusters =  39
# Res changed to 3.0500000000000007
# Initializing cluster centers with louvain, resolution =  3.150000000000001
# Epoch  0
# Epoch  10
# Res =  3.150000000000001 Num of clusters =  40
# Res changed to 3.150000000000001
# Initializing cluster centers with louvain, resolution =  3.250000000000001
# Epoch  0
# Epoch  10
# Res =  3.250000000000001 Num of clusters =  41
# Res changed to 3.250000000000001
# Initializing cluster centers with louvain, resolution =  3.350000000000001
# Epoch  0
# Epoch  10
# Res =  3.350000000000001 Num of clusters =  44
# Res changed to 3.350000000000001
# Initializing cluster centers with louvain, resolution =  3.450000000000001
# Epoch  0
# Epoch  10
# Res =  3.450000000000001 Num of clusters =  46
# Res changed to 3.450000000000001
# Initializing cluster centers with louvain, resolution =  3.550000000000001
# Epoch  0
# Epoch  10
# Res =  3.550000000000001 Num of clusters =  49
# recommended res =  3.550000000000001
# Initializing cluster centers with louvain, resolution =  3.550000000000001
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# delta_label  0.004018864055771991 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 43
# Calculateing adj matrix using xy only...
# Run 1: l [0.01, 100], p [0.0, 12.137574195861816]
# Run 2: l [0.01, 50.005], p [0.0, 2.731995105743408]
# Run 3: l [25.0075, 50.005], p [0.37146270275115967, 2.731995105743408]
# Run 4: l [25.0075, 37.50625], p [0.37146270275115967, 1.3042471408843994]
# Run 5: l [25.0075, 31.256875], p [0.37146270275115967, 0.7691370248794556]
# Run 6: l [25.0075, 28.1321875], p [0.37146270275115967, 0.5522950887680054]
# Run 7: l [26.56984375, 28.1321875], p [0.4572920799255371, 0.5522950887680054]
# recommended l =  27.351015625000002
# Start at res =  0.5 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.5
# Epoch  0
# Epoch  10
# Res =  0.5 Num of clusters =  20
# Initializing cluster centers with louvain, resolution =  0.4
# Epoch  0
# Epoch  10
# Res =  0.4 Num of clusters =  20
# Res changed to 0.4
# Initializing cluster centers with louvain, resolution =  0.30000000000000004
# Epoch  0
# Epoch  10
# Res =  0.30000000000000004 Num of clusters =  18
# Res changed to 0.30000000000000004
# Initializing cluster centers with louvain, resolution =  0.20000000000000004
# Epoch  0
# Epoch  10
# Res =  0.20000000000000004 Num of clusters =  16
# Res changed to 0.20000000000000004
# Initializing cluster centers with louvain, resolution =  0.10000000000000003
# Epoch  0
# Epoch  10
# Res =  0.10000000000000003 Num of clusters =  10
# Res changed to 0.10000000000000003
# Initializing cluster centers with louvain, resolution =  2.7755575615628914e-17
# Epoch  0
# delta_label  0.0 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 1
# Res =  2.7755575615628914e-17 Num of clusters =  1
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.05000000000000003
# Epoch  0
# Epoch  10
# Res =  0.05000000000000003 Num of clusters =  5
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.07500000000000004
# Epoch  0
# Epoch  10
# delta_label  0.004716013942997745 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 16
# Res =  0.07500000000000004 Num of clusters =  8
# Res changed to 0.07500000000000004
# Initializing cluster centers with louvain, resolution =  0.05000000000000004
# Epoch  0
# Epoch  10
# Res =  0.05000000000000004 Num of clusters =  5
# Step changed to 0.0125
# Initializing cluster centers with louvain, resolution =  0.06250000000000004
# Epoch  0
# Epoch  10
# Res =  0.06250000000000004 Num of clusters =  7
# Res changed to 0.06250000000000004
# Initializing cluster centers with louvain, resolution =  0.050000000000000044
# Epoch  0
# Epoch  10
# Res =  0.050000000000000044 Num of clusters =  5
# Step changed to 0.00625
# Initializing cluster centers with louvain, resolution =  0.05625000000000004
# Epoch  0
# Epoch  10
# Res =  0.05625000000000004 Num of clusters =  7
# Res changed to 0.05625000000000004
# Initializing cluster centers with louvain, resolution =  0.050000000000000044
# Epoch  0
# Epoch  10
# Res =  0.050000000000000044 Num of clusters =  5
# Step changed to 0.003125
# Exact resolution not found
# Recommended res =  0.05625000000000004
# Initializing cluster centers with louvain, resolution =  0.05625000000000004
# Epoch  0
# Epoch  10
# Epoch  20
# delta_label  0.00336272298544187 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 22
# Calculateing adj matrix using xy only...
# Start at res =  0.65 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.65
# Epoch  0
# Epoch  10
# Res =  0.65 Num of clusters =  19
# Initializing cluster centers with louvain, resolution =  0.55
# Epoch  0
# Epoch  10
# Res =  0.55 Num of clusters =  20
# Res changed to 0.55
# Initializing cluster centers with louvain, resolution =  0.45000000000000007
# Epoch  0
# Epoch  10
# Res =  0.45000000000000007 Num of clusters =  20
# Res changed to 0.45000000000000007
# Initializing cluster centers with louvain, resolution =  0.3500000000000001
# Epoch  0
# Epoch  10
# Res =  0.3500000000000001 Num of clusters =  19
# Res changed to 0.3500000000000001
# Initializing cluster centers with louvain, resolution =  0.2500000000000001
# Epoch  0
# Epoch  10
# Res =  0.2500000000000001 Num of clusters =  17
# Res changed to 0.2500000000000001
# Initializing cluster centers with louvain, resolution =  0.1500000000000001
# Epoch  0
# Epoch  10
# delta_label  0.0046339963092064795 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 19
# Res =  0.1500000000000001 Num of clusters =  13
# Res changed to 0.1500000000000001
# Initializing cluster centers with louvain, resolution =  0.0500000000000001
# Epoch  0
# Epoch  10
# Res =  0.0500000000000001 Num of clusters =  5
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.1000000000000001
# Epoch  0
# Epoch  10
# Res =  0.1000000000000001 Num of clusters =  10
# Res changed to 0.1000000000000001
# Initializing cluster centers with louvain, resolution =  0.0500000000000001
# Epoch  0
# Epoch  10
# Res =  0.0500000000000001 Num of clusters =  5
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.0750000000000001
# Epoch  0
# Epoch  10
# delta_label  0.004716013942997745 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 16
# Res =  0.0750000000000001 Num of clusters =  8
# Step changed to 0.0125
# Initializing cluster centers with louvain, resolution =  0.0875000000000001
# Epoch  0
# Epoch  10
# Res =  0.0875000000000001 Num of clusters =  9
# recommended res =  0.0875000000000001
# Initializing cluster centers with louvain, resolution =  0.0875000000000001
# Epoch  0
# Epoch  10
# Epoch  20
# delta_label  0.004141890506458888 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 22
# Calculateing adj matrix using xy only...
# Start at res =  1.05 step =  0.1
# Initializing cluster centers with louvain, resolution =  1.05
# Epoch  0
# Epoch  10
# Res =  1.05 Num of clusters =  25
# Initializing cluster centers with louvain, resolution =  0.9500000000000001
# Epoch  0
# Epoch  10
# Res =  0.9500000000000001 Num of clusters =  23
# Res changed to 0.9500000000000001
# Initializing cluster centers with louvain, resolution =  0.8500000000000001
# Epoch  0
# Epoch  10
# Res =  0.8500000000000001 Num of clusters =  23
# Res changed to 0.8500000000000001
# Initializing cluster centers with louvain, resolution =  0.7500000000000001
# Epoch  0
# Epoch  10
# Res =  0.7500000000000001 Num of clusters =  22
# Res changed to 0.7500000000000001
# Initializing cluster centers with louvain, resolution =  0.6500000000000001
# Epoch  0
# Epoch  10
# Res =  0.6500000000000001 Num of clusters =  19
# Res changed to 0.6500000000000001
# Initializing cluster centers with louvain, resolution =  0.5500000000000002
# Epoch  0
# Epoch  10
# Res =  0.5500000000000002 Num of clusters =  20
# Res changed to 0.5500000000000002
# Initializing cluster centers with louvain, resolution =  0.4500000000000002
# Epoch  0
# Epoch  10
# Res =  0.4500000000000002 Num of clusters =  20
# Res changed to 0.4500000000000002
# Initializing cluster centers with louvain, resolution =  0.3500000000000002
# Epoch  0
# Epoch  10
# Res =  0.3500000000000002 Num of clusters =  19
# Res changed to 0.3500000000000002
# Initializing cluster centers with louvain, resolution =  0.2500000000000002
# Epoch  0
# Epoch  10
# Res =  0.2500000000000002 Num of clusters =  17
# recommended res =  0.2500000000000002
# Initializing cluster centers with louvain, resolution =  0.2500000000000002
# Epoch  0
# Epoch  10
# Epoch  20
# delta_label  0.0036907935206069303 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 22
# Calculateing adj matrix using xy only...
# Start at res =  2.6500000000000004 step =  0.1
# Initializing cluster centers with louvain, resolution =  2.6500000000000004
# Epoch  0
# Epoch  10
# Res =  2.6500000000000004 Num of clusters =  37
# Initializing cluster centers with louvain, resolution =  2.7500000000000004
# Epoch  0
# Epoch  10
# Res =  2.7500000000000004 Num of clusters =  38
# Res changed to 2.7500000000000004
# Initializing cluster centers with louvain, resolution =  2.8500000000000005
# Epoch  0
# Epoch  10
# Res =  2.8500000000000005 Num of clusters =  38
# Res changed to 2.8500000000000005
# Initializing cluster centers with louvain, resolution =  2.9500000000000006
# Epoch  0
# Epoch  10
# Res =  2.9500000000000006 Num of clusters =  38
# Res changed to 2.9500000000000006
# Initializing cluster centers with louvain, resolution =  3.0500000000000007
# Epoch  0
# Epoch  10
# Res =  3.0500000000000007 Num of clusters =  41
# Res changed to 3.0500000000000007
# Initializing cluster centers with louvain, resolution =  3.150000000000001
# Epoch  0
# Epoch  10
# Res =  3.150000000000001 Num of clusters =  40
# Res changed to 3.150000000000001
# Initializing cluster centers with louvain, resolution =  3.250000000000001
# Epoch  0
# Epoch  10
# Res =  3.250000000000001 Num of clusters =  40
# Res changed to 3.250000000000001
# Initializing cluster centers with louvain, resolution =  3.350000000000001
# Epoch  0
# Epoch  10
# Res =  3.350000000000001 Num of clusters =  40
# Res changed to 3.350000000000001
# Initializing cluster centers with louvain, resolution =  3.450000000000001
# Epoch  0
# Epoch  10
# Res =  3.450000000000001 Num of clusters =  42
# Res changed to 3.450000000000001
# Initializing cluster centers with louvain, resolution =  3.550000000000001
# Epoch  0
# Epoch  10
# Res =  3.550000000000001 Num of clusters =  43
# Res changed to 3.550000000000001
# Initializing cluster centers with louvain, resolution =  3.6500000000000012
# Epoch  0
# Epoch  10
# Res =  3.6500000000000012 Num of clusters =  44
# Res changed to 3.6500000000000012
# Initializing cluster centers with louvain, resolution =  3.7500000000000013
# Epoch  0
# Epoch  10
# Res =  3.7500000000000013 Num of clusters =  43
# Res changed to 3.7500000000000013
# Initializing cluster centers with louvain, resolution =  3.8500000000000014
# Epoch  0
